# %% [markdown]
# <a href="https://colab.research.google.com/github/lifeisbeautifu1/deep-learning/blob/main/DCGAN_cifar10_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# example of a dcgan on cifar10
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(32, 32, 3)):
  model = Sequential()
  # normal
  model.add(Conv2D(64, (3, 3), padding='same', input_shape=in_shape))
  model.add(LeakyReLU(alpha=0.2))
  # downsample
  model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # downsample
  model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # downsample
  model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # classifier
  model.add(Flatten())
  model.add(Dropout(0.4))
  model.add(Dense(1, activation='sigmoid'))
  # compile model
  opt = Adam(lr=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# define the standalone generator model
def define_generator(latent_dim):
  model = Sequential()
  # foundation for 4x4 image
  n_nodes = 256 * 4 * 4
  model.add(Dense(n_nodes, input_dim=latent_dim))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Reshape((4, 4, 256)))
  # upsample to 8x8
  model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # upsample to 16x16
  model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # upsample to 32x32
  model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  # output layer
  model.add(Conv2D(3, (3, 3), activation='tanh', padding='same'))
  return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
  # make weights in the discriminator not trainable
  d_model.trainable = False
  # connect them
  model = Sequential()
  # add generator
  model.add(g_model)
  # add the discriminator
  model.add(d_model)
  # compile model
  opt = Adam(lr=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt)
  return model

# load and prepare cifar10 training images
def load_real_samples():
  # load cifar10 dataset
  (trainX, _), (_, _) = load_data()
  # convert from unsigned ints to floats
  X = trainX.astype('float32')
  # scale from [0, 255] to [-1, 1]
  X = (X - 127.5) / 127.5
  return X

# select real samples
def generate_real_samples(dataset, n_samples):
  # choose random instances
  ix = randint(0, dataset.shape[0], n_samples)
  # retrieve selected images
  X = dataset[ix]
  # generate 'real' class labels (1)
  y = ones((n_samples, 1))
  return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
  # generate points in the latent space
  x_input = randn(latent_dim * n_samples)
  # reshape into a batch of inputs for the network
  x_input = x_input.reshape(n_samples, latent_dim)
  return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
  # generate points in latent space
  x_input = generate_latent_points(latent_dim, n_samples)
  # predict outputs
  X = g_model.predict(x_input)
  # create 'fake' class labels (0)
  y = zeros((n_samples, 1))
  return X, y

# create and save a plot of generated images
def save_plot(examples, epoch, n=7):
  # scale from [-1, 1] to [0, 1]
  examples = (examples + 1) / 2.0
  # plot images
  for i in range(n * n):
    # define subplot
    pyplot.subplot(n, n, 1 + i)
    # turn off axis
    pyplot.axis('off')
    # plot raw pixel data
    pyplot.imshow(examples[i])
    # save plot to file
    filename = 'generated_plot_e%03d.png' % (epoch + 1)
    pyplot.savefig(filename)
    pyplot.close()

# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=150):
  # prepare real samples
  X_real, y_real = generate_real_samples(dataset, n_samples)
  # evaluate discriminator on real examples
  _, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
  # prepare fake examples
  x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
  # evaluate discriminator on fake examples
  _, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
  # summarize discriminator performance
  print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real * 100, acc_fake * 100))
  # save plot
  save_plot(x_fake, epoch)
  # save the generator model tile file
  filename = 'generator_model_%03d.h5' % (epoch + 1)
  g_model.save(filename)

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=10, n_batch=128):
  bat_per_epo = int(dataset.shape[0] / n_batch)
  half_batch = int(n_batch / 2)
  # manually enumerate epochs
  for i in range(n_epochs):
    # enumerate batches over the training set
    for j in range(bat_per_epo):
      # get randomly selected 'real' samples
      X_real, y_real = generate_real_samples(dataset, half_batch)
      # update discriminator model weights
      d_loss1, _ = d_model.train_on_batch(X_real, y_real)
      # generate 'fake' examples
      X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
      # update discriminator model weights
      d_loss2, _ = d_model.train_on_batch(X_fake, y_fake)
      # prepare points in latent space as input for the generator
      X_gan = generate_latent_points(latent_dim, n_batch)
      # create inverted labels for the fake samples
      y_gan = ones((n_batch, 1))
      # update the generator via the discriminator's error
      g_loss = gan_model.train_on_batch(X_gan, y_gan)
      # summarize loss on this batch
      print('>%d, %d/%d, d1=%.3f, d2=%.3f g=%.3f' %
      (i + 1, j + 1, bat_per_epo, d_loss1, d_loss2, g_loss))
      # evaluate the model performance, sometimes
      if (i + 1) % 10 == 0:
        summarize_performance(i, g_model, d_model, dataset, latent_dim)

# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Streaming output truncated to the last 5000 lines.
# 2/2 [==============================] - 0s 5ms/step
# >3, 233/390, d1=0.679, d2=0.673 g=1.037
# 2/2 [==============================] - 0s 5ms/step
# >3, 234/390, d1=0.574, d2=0.620 g=1.079
# 2/2 [==============================] - 0s 5ms/step
# >3, 235/390, d1=0.533, d2=0.846 g=1.289
# 2/2 [==============================] - 0s 5ms/step
# >3, 236/390, d1=0.653, d2=0.538 g=1.431
# 2/2 [==============================] - 0s 5ms/step
# >3, 237/390, d1=0.724, d2=0.524 g=1.418
# 2/2 [==============================] - 0s 5ms/step
# >3, 238/390, d1=0.762, d2=0.532 g=1.333
# 2/2 [==============================] - 0s 4ms/step
# >3, 239/390, d1=0.667, d2=0.551 g=1.185
# 2/2 [==============================] - 0s 7ms/step
# >3, 240/390, d1=0.620, d2=0.710 g=1.207
# 2/2 [==============================] - 0s 5ms/step
# >3, 241/390, d1=0.616, d2=0.636 g=1.231
# 2/2 [==============================] - 0s 5ms/step
# >3, 242/390, d1=0.639, d2=0.634 g=1.160
# 2/2 [==============================] - 0s 6ms/step
# >3, 243/390, d1=0.675, d2=0.656 g=1.102
# 2/2 [==============================] - 0s 4ms/step
# >3, 244/390, d1=0.695, d2=0.740 g=1.066
# 2/2 [==============================] - 0s 5ms/step
# >3, 245/390, d1=0.618, d2=0.647 g=1.261
# 2/2 [==============================] - 0s 5ms/step
# >3, 246/390, d1=0.619, d2=0.575 g=1.292
# 2/2 [==============================] - 0s 4ms/step
# >3, 247/390, d1=0.567, d2=0.521 g=1.421
# 2/2 [==============================] - 0s 4ms/step
# >3, 248/390, d1=0.496, d2=0.618 g=1.385
# 2/2 [==============================] - 0s 5ms/step
# >3, 249/390, d1=0.558, d2=0.838 g=1.485
# 2/2 [==============================] - 0s 5ms/step
# >3, 250/390, d1=0.669, d2=1.518 g=0.845
# 2/2 [==============================] - 0s 5ms/step
# >3, 251/390, d1=0.819, d2=3.275 g=1.025
# 2/2 [==============================] - 0s 5ms/step
# >3, 252/390, d1=0.800, d2=0.652 g=1.064
# 2/2 [==============================] - 0s 4ms/step
# >3, 253/390, d1=0.874, d2=0.679 g=1.039
# 2/2 [==============================] - 0s 4ms/step
# >3, 254/390, d1=0.716, d2=0.602 g=1.061
# 2/2 [==============================] - 0s 6ms/step
# >3, 255/390, d1=0.719, d2=0.591 g=1.107
# 2/2 [==============================] - 0s 5ms/step
# >3, 256/390, d1=0.725, d2=0.625 g=1.129
# 2/2 [==============================] - 0s 5ms/step
# >3, 257/390, d1=0.743, d2=0.647 g=1.134
# 2/2 [==============================] - 0s 4ms/step
# >3, 258/390, d1=0.677, d2=0.643 g=1.025
# 2/2 [==============================] - 0s 5ms/step
# >3, 259/390, d1=0.661, d2=0.732 g=1.013
# 2/2 [==============================] - 0s 5ms/step
# >3, 260/390, d1=0.802, d2=0.826 g=1.149
# 2/2 [==============================] - 0s 5ms/step
# >3, 261/390, d1=0.756, d2=0.555 g=1.257
# 2/2 [==============================] - 0s 5ms/step
# >3, 262/390, d1=0.777, d2=0.676 g=1.213
# 2/2 [==============================] - 0s 4ms/step
# >3, 263/390, d1=0.791, d2=0.591 g=1.140
# 2/2 [==============================] - 0s 4ms/step
# >3, 264/390, d1=0.665, d2=0.666 g=1.063
# 2/2 [==============================] - 0s 4ms/step
# >3, 265/390, d1=0.581, d2=0.619 g=1.044
# 2/2 [==============================] - 0s 4ms/step
# >3, 266/390, d1=0.609, d2=0.683 g=1.040
# 2/2 [==============================] - 0s 5ms/step
# >3, 267/390, d1=0.627, d2=0.718 g=0.971
# 2/2 [==============================] - 0s 5ms/step
# >3, 268/390, d1=0.638, d2=0.716 g=1.050
# 2/2 [==============================] - 0s 5ms/step
# >3, 269/390, d1=0.665, d2=0.634 g=1.215
# 2/2 [==============================] - 0s 5ms/step
# >3, 270/390, d1=0.714, d2=0.678 g=1.170
# 2/2 [==============================] - 0s 7ms/step
# >3, 271/390, d1=0.796, d2=0.735 g=1.054
# 2/2 [==============================] - 0s 4ms/step
# >3, 272/390, d1=0.830, d2=0.640 g=1.118
# 2/2 [==============================] - 0s 5ms/step
# >3, 273/390, d1=0.702, d2=0.606 g=1.430
# 2/2 [==============================] - 0s 5ms/step
# >3, 274/390, d1=0.766, d2=0.464 g=1.404
# 2/2 [==============================] - 0s 4ms/step
# >3, 275/390, d1=0.730, d2=0.609 g=1.193
# 2/2 [==============================] - 0s 3ms/step
# >3, 276/390, d1=0.816, d2=0.804 g=1.065
# 2/2 [==============================] - 0s 6ms/step
# >3, 277/390, d1=0.753, d2=0.711 g=1.079
# 2/2 [==============================] - 0s 4ms/step
# >3, 278/390, d1=0.755, d2=0.642 g=1.177
# 2/2 [==============================] - 0s 5ms/step
# >3, 279/390, d1=0.738, d2=0.601 g=1.206
# 2/2 [==============================] - 0s 6ms/step
# >3, 280/390, d1=0.740, d2=0.625 g=0.994
# 2/2 [==============================] - 0s 6ms/step
# >3, 281/390, d1=0.725, d2=0.706 g=0.916
# 2/2 [==============================] - 0s 5ms/step
# >3, 282/390, d1=0.718, d2=0.731 g=0.877
# 2/2 [==============================] - 0s 6ms/step
# >3, 283/390, d1=0.684, d2=0.724 g=0.910
# 2/2 [==============================] - 0s 4ms/step
# >3, 284/390, d1=0.627, d2=0.684 g=0.927
# 2/2 [==============================] - 0s 4ms/step
# >3, 285/390, d1=0.675, d2=0.667 g=0.935
# 2/2 [==============================] - 0s 5ms/step
# >3, 286/390, d1=0.703, d2=0.656 g=0.963
# 2/2 [==============================] - 0s 4ms/step
# >3, 287/390, d1=0.668, d2=0.620 g=1.091
# 2/2 [==============================] - 0s 5ms/step
# >3, 288/390, d1=0.649, d2=0.551 g=1.119
# 2/2 [==============================] - 0s 3ms/step
# >3, 289/390, d1=0.606, d2=0.593 g=1.163
# 2/2 [==============================] - 0s 4ms/step
# >3, 290/390, d1=0.575, d2=0.605 g=1.235
# 2/2 [==============================] - 0s 4ms/step
# >3, 291/390, d1=0.556, d2=0.592 g=1.227
# 2/2 [==============================] - 0s 5ms/step
# >3, 292/390, d1=0.612, d2=0.628 g=1.175
# 2/2 [==============================] - 0s 7ms/step
# >3, 293/390, d1=0.430, d2=0.812 g=1.239
# 2/2 [==============================] - 0s 4ms/step
# >3, 294/390, d1=0.619, d2=0.733 g=1.257
# 2/2 [==============================] - 0s 4ms/step
# >3, 295/390, d1=0.670, d2=0.671 g=1.166
# 2/2 [==============================] - 0s 4ms/step
# >3, 296/390, d1=0.672, d2=0.840 g=1.281
# 2/2 [==============================] - 0s 4ms/step
# >3, 297/390, d1=0.698, d2=0.551 g=1.310
# 2/2 [==============================] - 0s 19ms/step
# >3, 298/390, d1=0.750, d2=0.589 g=1.113
# 2/2 [==============================] - 0s 5ms/step
# >3, 299/390, d1=0.705, d2=0.599 g=1.222
# 2/2 [==============================] - 0s 6ms/step
# >3, 300/390, d1=0.559, d2=0.499 g=1.367
# 2/2 [==============================] - 0s 7ms/step
# >3, 301/390, d1=0.530, d2=0.503 g=1.501
# 2/2 [==============================] - 0s 6ms/step
# >3, 302/390, d1=0.519, d2=0.683 g=1.416
# 2/2 [==============================] - 0s 5ms/step
# >3, 303/390, d1=0.649, d2=0.588 g=1.204
# 2/2 [==============================] - 0s 5ms/step
# >3, 304/390, d1=0.658, d2=0.810 g=1.134
# 2/2 [==============================] - 0s 5ms/step
# >3, 305/390, d1=0.602, d2=0.532 g=1.265
# 2/2 [==============================] - 0s 4ms/step
# >3, 306/390, d1=0.599, d2=0.597 g=1.193
# 2/2 [==============================] - 0s 4ms/step
# >3, 307/390, d1=0.506, d2=0.864 g=1.047
# 2/2 [==============================] - 0s 4ms/step
# >3, 308/390, d1=0.635, d2=0.800 g=1.117
# 2/2 [==============================] - 0s 5ms/step
# >3, 309/390, d1=0.723, d2=0.840 g=1.294
# 2/2 [==============================] - 0s 5ms/step
# >3, 310/390, d1=0.737, d2=0.597 g=1.312
# 2/2 [==============================] - 0s 5ms/step
# >3, 311/390, d1=0.656, d2=0.541 g=1.426
# 2/2 [==============================] - 0s 4ms/step
# >3, 312/390, d1=0.481, d2=0.620 g=1.747
# 2/2 [==============================] - 0s 4ms/step
# >3, 313/390, d1=0.625, d2=0.373 g=1.783
# 2/2 [==============================] - 0s 4ms/step
# >3, 314/390, d1=0.620, d2=0.643 g=1.395
# 2/2 [==============================] - 0s 5ms/step
# >3, 315/390, d1=0.494, d2=0.741 g=1.283
# 2/2 [==============================] - 0s 5ms/step
# >3, 316/390, d1=0.662, d2=0.945 g=1.376
# 2/2 [==============================] - 0s 5ms/step
# >3, 317/390, d1=0.819, d2=0.435 g=1.581
# 2/2 [==============================] - 0s 5ms/step
# >3, 318/390, d1=0.814, d2=0.444 g=1.431
# 2/2 [==============================] - 0s 7ms/step
# >3, 319/390, d1=0.711, d2=0.564 g=1.113
# 2/2 [==============================] - 0s 5ms/step
# >3, 320/390, d1=0.630, d2=0.614 g=1.082
# 2/2 [==============================] - 0s 6ms/step
# >3, 321/390, d1=0.554, d2=0.667 g=1.181
# 2/2 [==============================] - 0s 5ms/step
# >3, 322/390, d1=0.734, d2=0.597 g=1.218
# 2/2 [==============================] - 0s 6ms/step
# >3, 323/390, d1=0.773, d2=0.601 g=1.212
# 2/2 [==============================] - 0s 5ms/step
# >3, 324/390, d1=0.632, d2=0.595 g=1.233
# 2/2 [==============================] - 0s 5ms/step
# >3, 325/390, d1=0.671, d2=0.628 g=1.230
# 2/2 [==============================] - 0s 4ms/step
# >3, 326/390, d1=0.669, d2=0.618 g=1.291
# 2/2 [==============================] - 0s 5ms/step
# >3, 327/390, d1=0.607, d2=0.626 g=1.303
# 2/2 [==============================] - 0s 5ms/step
# >3, 328/390, d1=0.617, d2=0.791 g=1.254
# 2/2 [==============================] - 0s 3ms/step
# >3, 329/390, d1=0.753, d2=0.743 g=1.233
# 2/2 [==============================] - 0s 5ms/step
# >3, 330/390, d1=0.647, d2=0.568 g=1.376
# 2/2 [==============================] - 0s 5ms/step
# >3, 331/390, d1=0.733, d2=0.577 g=1.385
# 2/2 [==============================] - 0s 4ms/step
# >3, 332/390, d1=0.576, d2=0.662 g=1.582
# 2/2 [==============================] - 0s 5ms/step
# >3, 333/390, d1=0.685, d2=0.672 g=1.171
# 2/2 [==============================] - 0s 5ms/step
# >3, 334/390, d1=0.711, d2=0.849 g=1.141
# 2/2 [==============================] - 0s 5ms/step
# >3, 335/390, d1=0.776, d2=0.617 g=1.137
# 2/2 [==============================] - 0s 6ms/step
# >3, 336/390, d1=0.835, d2=0.589 g=0.993
# 2/2 [==============================] - 0s 7ms/step
# >3, 337/390, d1=0.658, d2=0.646 g=1.021
# 2/2 [==============================] - 0s 4ms/step
# >3, 338/390, d1=0.692, d2=0.624 g=1.053
# 2/2 [==============================] - 0s 4ms/step
# >3, 339/390, d1=0.602, d2=0.619 g=1.078
# 2/2 [==============================] - 0s 5ms/step
# >3, 340/390, d1=0.635, d2=0.544 g=1.172
# 2/2 [==============================] - 0s 6ms/step
# >3, 341/390, d1=0.604, d2=0.585 g=1.169
# 2/2 [==============================] - 0s 4ms/step
# >3, 342/390, d1=0.569, d2=0.721 g=1.107
# 2/2 [==============================] - 0s 6ms/step
# >3, 343/390, d1=0.521, d2=0.766 g=1.166
# 2/2 [==============================] - 0s 4ms/step
# >3, 344/390, d1=0.636, d2=1.059 g=1.242
# 2/2 [==============================] - 0s 5ms/step
# >3, 345/390, d1=0.808, d2=0.540 g=1.242
# 2/2 [==============================] - 0s 5ms/step
# >3, 346/390, d1=0.723, d2=0.474 g=1.363
# 2/2 [==============================] - 0s 4ms/step
# >3, 347/390, d1=0.580, d2=0.621 g=1.500
# 2/2 [==============================] - 0s 4ms/step
# >3, 348/390, d1=0.593, d2=0.813 g=1.467
# 2/2 [==============================] - 0s 5ms/step
# >3, 349/390, d1=0.787, d2=0.485 g=1.347
# 2/2 [==============================] - 0s 4ms/step
# >3, 350/390, d1=0.886, d2=0.471 g=1.224
# 2/2 [==============================] - 0s 4ms/step
# >3, 351/390, d1=0.605, d2=0.576 g=1.202
# 2/2 [==============================] - 0s 5ms/step
# >3, 352/390, d1=0.604, d2=0.533 g=1.268
# 2/2 [==============================] - 0s 4ms/step
# >3, 353/390, d1=0.551, d2=0.585 g=1.283
# 2/2 [==============================] - 0s 5ms/step
# >3, 354/390, d1=0.528, d2=0.503 g=1.311
# 2/2 [==============================] - 0s 4ms/step
# >3, 355/390, d1=0.474, d2=0.500 g=1.342
# 2/2 [==============================] - 0s 4ms/step
# >3, 356/390, d1=0.444, d2=0.655 g=1.318
# 2/2 [==============================] - 0s 5ms/step
# >3, 357/390, d1=0.453, d2=0.802 g=1.357
# 2/2 [==============================] - 0s 7ms/step
# >3, 358/390, d1=0.667, d2=0.689 g=1.504
# 2/2 [==============================] - 0s 5ms/step
# >3, 359/390, d1=0.733, d2=0.561 g=1.370
# 2/2 [==============================] - 0s 5ms/step
# >3, 360/390, d1=0.810, d2=0.564 g=1.252
# 2/2 [==============================] - 0s 4ms/step
# >3, 361/390, d1=0.670, d2=0.739 g=1.269
# 2/2 [==============================] - 0s 5ms/step
# >3, 362/390, d1=0.711, d2=0.697 g=1.295
# 2/2 [==============================] - 0s 4ms/step
# >3, 363/390, d1=0.801, d2=0.749 g=1.342
# 2/2 [==============================] - 0s 5ms/step
# >3, 364/390, d1=0.771, d2=0.528 g=1.451
# 2/2 [==============================] - 0s 5ms/step
# >3, 365/390, d1=0.835, d2=0.538 g=1.706
# 2/2 [==============================] - 0s 5ms/step
# >3, 366/390, d1=0.654, d2=0.450 g=1.552
# 2/2 [==============================] - 0s 6ms/step
# >3, 367/390, d1=0.683, d2=0.663 g=1.263
# 2/2 [==============================] - 0s 4ms/step
# >3, 368/390, d1=0.589, d2=1.027 g=1.098
# 2/2 [==============================] - 0s 4ms/step
# >3, 369/390, d1=0.748, d2=0.955 g=1.118
# 2/2 [==============================] - 0s 6ms/step
# >3, 370/390, d1=0.844, d2=0.552 g=1.045
# 2/2 [==============================] - 0s 5ms/step
# >3, 371/390, d1=0.729, d2=0.582 g=0.975
# 2/2 [==============================] - 0s 6ms/step
# >3, 372/390, d1=0.655, d2=0.696 g=0.996
# 2/2 [==============================] - 0s 4ms/step
# >3, 373/390, d1=0.552, d2=0.674 g=1.044
# 2/2 [==============================] - 0s 7ms/step
# >3, 374/390, d1=0.611, d2=0.711 g=1.212
# 2/2 [==============================] - 0s 5ms/step
# >3, 375/390, d1=0.663, d2=0.595 g=1.216
# 2/2 [==============================] - 0s 6ms/step
# >3, 376/390, d1=0.558, d2=0.490 g=1.380
# 2/2 [==============================] - 0s 5ms/step
# >3, 377/390, d1=0.548, d2=0.422 g=1.416
# 2/2 [==============================] - 0s 4ms/step
# >3, 378/390, d1=0.548, d2=0.486 g=1.308
# 2/2 [==============================] - 0s 4ms/step
# >3, 379/390, d1=0.560, d2=0.562 g=1.232
# 2/2 [==============================] - 0s 4ms/step
# >3, 380/390, d1=0.417, d2=0.794 g=1.200
# 2/2 [==============================] - 0s 6ms/step
# >3, 381/390, d1=0.466, d2=0.661 g=1.273
# 2/2 [==============================] - 0s 6ms/step
# >3, 382/390, d1=0.638, d2=0.692 g=1.128
# 2/2 [==============================] - 0s 6ms/step
# >3, 383/390, d1=0.635, d2=0.780 g=1.216
# 2/2 [==============================] - 0s 5ms/step
# >3, 384/390, d1=0.710, d2=0.838 g=1.472
# 2/2 [==============================] - 0s 6ms/step
# >3, 385/390, d1=0.767, d2=0.519 g=1.641
# 2/2 [==============================] - 0s 4ms/step
# >3, 386/390, d1=0.609, d2=0.534 g=1.555
# 2/2 [==============================] - 0s 5ms/step
# >3, 387/390, d1=0.629, d2=0.749 g=1.627
# 2/2 [==============================] - 0s 5ms/step
# >3, 388/390, d1=0.743, d2=0.449 g=1.766
# 2/2 [==============================] - 0s 5ms/step
# >3, 389/390, d1=0.630, d2=0.674 g=1.732
# 2/2 [==============================] - 0s 5ms/step
# >3, 390/390, d1=0.750, d2=0.601 g=1.640
# 2/2 [==============================] - 0s 5ms/step
# >4, 1/390, d1=0.850, d2=0.487 g=1.624
# 2/2 [==============================] - 0s 9ms/step
# >4, 2/390, d1=0.819, d2=0.586 g=1.539
# 2/2 [==============================] - 0s 5ms/step
# >4, 3/390, d1=0.698, d2=0.625 g=1.281
# 2/2 [==============================] - 0s 4ms/step
# >4, 4/390, d1=0.656, d2=0.747 g=1.223
# 2/2 [==============================] - 0s 5ms/step
# >4, 5/390, d1=0.498, d2=0.570 g=1.231
# 2/2 [==============================] - 0s 3ms/step
# >4, 6/390, d1=0.597, d2=0.664 g=1.055
# 2/2 [==============================] - 0s 5ms/step
# >4, 7/390, d1=0.542, d2=0.775 g=1.059
# 2/2 [==============================] - 0s 5ms/step
# >4, 8/390, d1=0.586, d2=0.900 g=1.197
# 2/2 [==============================] - 0s 5ms/step
# >4, 9/390, d1=0.675, d2=0.838 g=1.499
# 2/2 [==============================] - 0s 6ms/step
# >4, 10/390, d1=0.726, d2=0.329 g=1.870
# 2/2 [==============================] - 0s 4ms/step
# >4, 11/390, d1=0.631, d2=0.422 g=1.562
# 2/2 [==============================] - 0s 5ms/step
# >4, 12/390, d1=0.521, d2=0.849 g=1.075
# 2/2 [==============================] - 0s 5ms/step
# >4, 13/390, d1=0.483, d2=1.211 g=1.039
# 2/2 [==============================] - 0s 4ms/step
# >4, 14/390, d1=0.615, d2=1.543 g=1.448
# 2/2 [==============================] - 0s 5ms/step
# >4, 15/390, d1=0.906, d2=0.476 g=1.265
# 2/2 [==============================] - 0s 5ms/step
# >4, 16/390, d1=0.797, d2=0.658 g=1.192
# 2/2 [==============================] - 0s 3ms/step
# >4, 17/390, d1=0.838, d2=0.649 g=1.077
# 2/2 [==============================] - 0s 4ms/step
# >4, 18/390, d1=0.776, d2=0.641 g=1.121
# 2/2 [==============================] - 0s 6ms/step
# >4, 19/390, d1=0.750, d2=0.525 g=1.314
# 2/2 [==============================] - 0s 5ms/step
# >4, 20/390, d1=0.723, d2=0.587 g=1.143
# 2/2 [==============================] - 0s 4ms/step
# >4, 21/390, d1=0.714, d2=0.699 g=1.036
# 2/2 [==============================] - 0s 3ms/step
# >4, 22/390, d1=0.711, d2=0.728 g=1.019
# 2/2 [==============================] - 0s 5ms/step
# >4, 23/390, d1=0.626, d2=0.631 g=0.976
# 2/2 [==============================] - 0s 5ms/step
# >4, 24/390, d1=0.666, d2=0.641 g=1.052
# 2/2 [==============================] - 0s 5ms/step
# >4, 25/390, d1=0.664, d2=0.615 g=1.196
# 2/2 [==============================] - 0s 3ms/step
# >4, 26/390, d1=0.660, d2=0.590 g=1.192
# 2/2 [==============================] - 0s 5ms/step
# >4, 27/390, d1=0.597, d2=0.603 g=1.138
# 2/2 [==============================] - 0s 5ms/step
# >4, 28/390, d1=0.545, d2=0.685 g=1.194
# 2/2 [==============================] - 0s 5ms/step
# >4, 29/390, d1=0.745, d2=0.682 g=1.069
# 2/2 [==============================] - 0s 5ms/step
# >4, 30/390, d1=0.607, d2=0.678 g=1.102
# 2/2 [==============================] - 0s 3ms/step
# >4, 31/390, d1=0.657, d2=0.554 g=1.276
# 2/2 [==============================] - 0s 5ms/step
# >4, 32/390, d1=0.758, d2=0.581 g=1.305
# 2/2 [==============================] - 0s 5ms/step
# >4, 33/390, d1=0.635, d2=0.584 g=1.139
# 2/2 [==============================] - 0s 3ms/step
# >4, 34/390, d1=0.584, d2=0.592 g=1.116
# 2/2 [==============================] - 0s 5ms/step
# >4, 35/390, d1=0.635, d2=0.633 g=1.138
# 2/2 [==============================] - 0s 5ms/step
# >4, 36/390, d1=0.713, d2=0.659 g=1.068
# 2/2 [==============================] - 0s 4ms/step
# >4, 37/390, d1=0.749, d2=0.629 g=1.035
# 2/2 [==============================] - 0s 4ms/step
# >4, 38/390, d1=0.610, d2=0.681 g=1.042
# 2/2 [==============================] - 0s 4ms/step
# >4, 39/390, d1=0.633, d2=0.656 g=0.991
# 2/2 [==============================] - 0s 3ms/step
# >4, 40/390, d1=0.618, d2=0.655 g=1.040
# 2/2 [==============================] - 0s 5ms/step
# >4, 41/390, d1=0.670, d2=0.681 g=1.068
# 2/2 [==============================] - 0s 6ms/step
# >4, 42/390, d1=0.634, d2=0.562 g=1.188
# 2/2 [==============================] - 0s 4ms/step
# >4, 43/390, d1=0.626, d2=0.523 g=1.406
# 2/2 [==============================] - 0s 5ms/step
# >4, 44/390, d1=0.609, d2=0.548 g=1.377
# 2/2 [==============================] - 0s 5ms/step
# >4, 45/390, d1=0.548, d2=0.772 g=1.346
# 2/2 [==============================] - 0s 4ms/step
# >4, 46/390, d1=0.721, d2=0.819 g=1.664
# 2/2 [==============================] - 0s 5ms/step
# >4, 47/390, d1=0.739, d2=0.412 g=1.570
# 2/2 [==============================] - 0s 5ms/step
# >4, 48/390, d1=0.595, d2=0.673 g=1.350
# 2/2 [==============================] - 0s 7ms/step
# >4, 49/390, d1=0.582, d2=0.743 g=1.174
# 2/2 [==============================] - 0s 7ms/step
# >4, 50/390, d1=0.654, d2=0.660 g=1.234
# 2/2 [==============================] - 0s 4ms/step
# >4, 51/390, d1=0.669, d2=0.580 g=1.186
# 2/2 [==============================] - 0s 4ms/step
# >4, 52/390, d1=0.676, d2=0.581 g=1.129
# 2/2 [==============================] - 0s 7ms/step
# >4, 53/390, d1=0.580, d2=0.665 g=1.270
# 2/2 [==============================] - 0s 7ms/step
# >4, 54/390, d1=0.611, d2=0.445 g=1.359
# 2/2 [==============================] - 0s 5ms/step
# >4, 55/390, d1=0.586, d2=0.502 g=1.289
# 2/2 [==============================] - 0s 4ms/step
# >4, 56/390, d1=0.546, d2=0.609 g=1.265
# 2/2 [==============================] - 0s 5ms/step
# >4, 57/390, d1=0.567, d2=0.724 g=1.360
# 2/2 [==============================] - 0s 7ms/step
# >4, 58/390, d1=0.583, d2=0.640 g=1.454
# 2/2 [==============================] - 0s 4ms/step
# >4, 59/390, d1=0.718, d2=0.835 g=1.677
# 2/2 [==============================] - 0s 5ms/step
# >4, 60/390, d1=0.718, d2=0.391 g=1.552
# 2/2 [==============================] - 0s 5ms/step
# >4, 61/390, d1=0.722, d2=0.628 g=1.345
# 2/2 [==============================] - 0s 5ms/step
# >4, 62/390, d1=0.726, d2=0.656 g=1.171
# 2/2 [==============================] - 0s 5ms/step
# >4, 63/390, d1=0.608, d2=0.775 g=1.131
# 2/2 [==============================] - 0s 5ms/step
# >4, 64/390, d1=0.629, d2=0.640 g=1.131
# 2/2 [==============================] - 0s 5ms/step
# >4, 65/390, d1=0.660, d2=0.558 g=1.131
# 2/2 [==============================] - 0s 5ms/step
# >4, 66/390, d1=0.655, d2=0.613 g=1.249
# 2/2 [==============================] - 0s 5ms/step
# >4, 67/390, d1=0.621, d2=0.532 g=1.276
# 2/2 [==============================] - 0s 5ms/step
# >4, 68/390, d1=0.664, d2=0.679 g=1.209
# 2/2 [==============================] - 0s 4ms/step
# >4, 69/390, d1=0.577, d2=0.816 g=1.365
# 2/2 [==============================] - 0s 5ms/step
# >4, 70/390, d1=0.697, d2=0.590 g=1.409
# 2/2 [==============================] - 0s 6ms/step
# >4, 71/390, d1=0.679, d2=0.584 g=1.599
# 2/2 [==============================] - 0s 5ms/step
# >4, 72/390, d1=0.695, d2=0.526 g=1.526
# 2/2 [==============================] - 0s 4ms/step
# >4, 73/390, d1=0.613, d2=0.668 g=1.256
# 2/2 [==============================] - 0s 5ms/step
# >4, 74/390, d1=0.719, d2=0.927 g=1.067
# 2/2 [==============================] - 0s 4ms/step
# >4, 75/390, d1=0.717, d2=0.784 g=1.089
# 2/2 [==============================] - 0s 3ms/step
# >4, 76/390, d1=0.662, d2=0.545 g=1.207
# 2/2 [==============================] - 0s 4ms/step
# >4, 77/390, d1=0.683, d2=0.479 g=1.181
# 2/2 [==============================] - 0s 5ms/step
# >4, 78/390, d1=0.651, d2=0.568 g=1.146
# 2/2 [==============================] - 0s 4ms/step
# >4, 79/390, d1=0.634, d2=0.583 g=1.160
# 2/2 [==============================] - 0s 3ms/step
# >4, 80/390, d1=0.678, d2=0.566 g=1.095
# 2/2 [==============================] - 0s 4ms/step
# >4, 81/390, d1=0.535, d2=0.589 g=1.104
# 2/2 [==============================] - 0s 5ms/step
# >4, 82/390, d1=0.598, d2=0.611 g=1.153
# 2/2 [==============================] - 0s 5ms/step
# >4, 83/390, d1=0.501, d2=0.551 g=1.233
# 2/2 [==============================] - 0s 4ms/step
# >4, 84/390, d1=0.461, d2=0.491 g=1.412
# 2/2 [==============================] - 0s 3ms/step
# >4, 85/390, d1=0.680, d2=0.616 g=1.426
# 2/2 [==============================] - 0s 5ms/step
# >4, 86/390, d1=0.607, d2=0.573 g=1.531
# 2/2 [==============================] - 0s 4ms/step
# >4, 87/390, d1=0.606, d2=0.659 g=1.340
# 2/2 [==============================] - 0s 4ms/step
# >4, 88/390, d1=0.623, d2=0.764 g=1.223
# 2/2 [==============================] - 0s 4ms/step
# >4, 89/390, d1=0.708, d2=0.797 g=1.392
# 2/2 [==============================] - 0s 6ms/step
# >4, 90/390, d1=0.726, d2=0.697 g=1.677
# 2/2 [==============================] - 0s 4ms/step
# >4, 91/390, d1=0.592, d2=0.432 g=1.720
# 2/2 [==============================] - 0s 7ms/step
# >4, 92/390, d1=0.597, d2=1.092 g=1.956
# 2/2 [==============================] - 0s 4ms/step
# >4, 93/390, d1=1.004, d2=0.855 g=1.429
# 2/2 [==============================] - 0s 5ms/step
# >4, 94/390, d1=0.805, d2=0.466 g=1.591
# 2/2 [==============================] - 0s 4ms/step
# >4, 95/390, d1=0.775, d2=0.540 g=1.768
# 2/2 [==============================] - 0s 4ms/step
# >4, 96/390, d1=0.622, d2=0.406 g=1.729
# 2/2 [==============================] - 0s 4ms/step
# >4, 97/390, d1=0.489, d2=0.753 g=2.335
# 2/2 [==============================] - 0s 4ms/step
# >4, 98/390, d1=0.786, d2=0.688 g=1.456
# 2/2 [==============================] - 0s 5ms/step
# >4, 99/390, d1=0.589, d2=0.868 g=1.510
# 2/2 [==============================] - 0s 5ms/step
# >4, 100/390, d1=0.784, d2=0.545 g=1.514
# 2/2 [==============================] - 0s 4ms/step
# >4, 101/390, d1=0.693, d2=0.572 g=1.345
# 2/2 [==============================] - 0s 4ms/step
# >4, 102/390, d1=0.442, d2=0.596 g=1.416
# 2/2 [==============================] - 0s 5ms/step
# >4, 103/390, d1=0.488, d2=0.812 g=1.234
# 2/2 [==============================] - 0s 4ms/step
# >4, 104/390, d1=0.584, d2=0.661 g=1.265
# 2/2 [==============================] - 0s 5ms/step
# >4, 105/390, d1=0.567, d2=0.870 g=1.492
# 2/2 [==============================] - 0s 4ms/step
# >4, 106/390, d1=0.660, d2=0.724 g=2.224
# 2/2 [==============================] - 0s 5ms/step
# >4, 107/390, d1=0.609, d2=0.421 g=1.890
# 2/2 [==============================] - 0s 5ms/step
# >4, 108/390, d1=0.584, d2=1.281 g=2.021
# 2/2 [==============================] - 0s 4ms/step
# >4, 109/390, d1=0.842, d2=0.694 g=1.551
# 2/2 [==============================] - 0s 5ms/step
# >4, 110/390, d1=0.686, d2=0.785 g=1.301
# 2/2 [==============================] - 0s 5ms/step
# >4, 111/390, d1=0.827, d2=0.699 g=1.419
# 2/2 [==============================] - 0s 5ms/step
# >4, 112/390, d1=0.874, d2=0.455 g=1.943
# 2/2 [==============================] - 0s 5ms/step
# >4, 113/390, d1=0.840, d2=0.442 g=1.803
# 2/2 [==============================] - 0s 10ms/step
# >4, 114/390, d1=0.682, d2=0.432 g=1.869
# 2/2 [==============================] - 0s 5ms/step
# >4, 115/390, d1=0.710, d2=0.660 g=1.133
# 2/2 [==============================] - 0s 6ms/step
# >4, 116/390, d1=0.631, d2=1.061 g=1.040
# 2/2 [==============================] - 0s 5ms/step
# >4, 117/390, d1=0.717, d2=0.778 g=0.906
# 2/2 [==============================] - 0s 5ms/step
# >4, 118/390, d1=0.651, d2=0.621 g=0.972
# 2/2 [==============================] - 0s 5ms/step
# >4, 119/390, d1=0.608, d2=0.561 g=1.034
# 2/2 [==============================] - 0s 5ms/step
# >4, 120/390, d1=0.520, d2=0.541 g=1.082
# 2/2 [==============================] - 0s 4ms/step
# >4, 121/390, d1=0.413, d2=0.592 g=1.045
# 2/2 [==============================] - 0s 5ms/step
# >4, 122/390, d1=0.486, d2=0.616 g=1.130
# 2/2 [==============================] - 0s 4ms/step
# >4, 123/390, d1=0.410, d2=0.696 g=1.171
# 2/2 [==============================] - 0s 4ms/step
# >4, 124/390, d1=0.500, d2=0.811 g=1.348
# 2/2 [==============================] - 0s 8ms/step
# >4, 125/390, d1=0.654, d2=0.712 g=1.613
# 2/2 [==============================] - 0s 6ms/step
# >4, 126/390, d1=0.677, d2=0.598 g=1.778
# 2/2 [==============================] - 0s 4ms/step
# >4, 127/390, d1=0.878, d2=0.597 g=1.751
# 2/2 [==============================] - 0s 5ms/step
# >4, 128/390, d1=0.859, d2=0.609 g=1.557
# 2/2 [==============================] - 0s 9ms/step
# >4, 129/390, d1=0.736, d2=0.595 g=1.337
# 2/2 [==============================] - 0s 5ms/step
# >4, 130/390, d1=0.780, d2=0.541 g=1.465
# 2/2 [==============================] - 0s 5ms/step
# >4, 131/390, d1=0.753, d2=0.616 g=1.499
# 2/2 [==============================] - 0s 5ms/step
# >4, 132/390, d1=0.732, d2=0.668 g=1.290
# 2/2 [==============================] - 0s 5ms/step
# >4, 133/390, d1=0.671, d2=0.656 g=1.133
# 2/2 [==============================] - 0s 4ms/step
# >4, 134/390, d1=0.863, d2=0.775 g=0.915
# 2/2 [==============================] - 0s 6ms/step
# >4, 135/390, d1=0.660, d2=0.727 g=0.888
# 2/2 [==============================] - 0s 5ms/step
# >4, 136/390, d1=0.642, d2=0.632 g=0.988
# 2/2 [==============================] - 0s 5ms/step
# >4, 137/390, d1=0.586, d2=0.563 g=1.125
# 2/2 [==============================] - 0s 4ms/step
# >4, 138/390, d1=0.571, d2=0.592 g=1.178
# 2/2 [==============================] - 0s 6ms/step
# >4, 139/390, d1=0.561, d2=0.608 g=1.211
# 2/2 [==============================] - 0s 5ms/step
# >4, 140/390, d1=0.659, d2=0.728 g=1.244
# 2/2 [==============================] - 0s 5ms/step
# >4, 141/390, d1=0.668, d2=0.755 g=1.176
# 2/2 [==============================] - 0s 5ms/step
# >4, 142/390, d1=0.732, d2=0.587 g=1.274
# 2/2 [==============================] - 0s 5ms/step
# >4, 143/390, d1=0.698, d2=0.553 g=1.415
# 2/2 [==============================] - 0s 4ms/step
# >4, 144/390, d1=0.707, d2=0.506 g=1.361
# 2/2 [==============================] - 0s 4ms/step
# >4, 145/390, d1=0.564, d2=0.574 g=1.331
# 2/2 [==============================] - 0s 5ms/step
# >4, 146/390, d1=0.612, d2=0.603 g=1.442
# 2/2 [==============================] - 0s 4ms/step
# >4, 147/390, d1=0.688, d2=0.587 g=1.422
# 2/2 [==============================] - 0s 4ms/step
# >4, 148/390, d1=0.629, d2=0.524 g=1.400
# 2/2 [==============================] - 0s 5ms/step
# >4, 149/390, d1=0.677, d2=0.682 g=1.199
# 2/2 [==============================] - 0s 4ms/step
# >4, 150/390, d1=0.780, d2=0.689 g=1.140
# 2/2 [==============================] - 0s 5ms/step
# >4, 151/390, d1=0.609, d2=0.597 g=1.071
# 2/2 [==============================] - 0s 4ms/step
# >4, 152/390, d1=0.631, d2=0.729 g=1.243
# 2/2 [==============================] - 0s 4ms/step
# >4, 153/390, d1=0.690, d2=0.531 g=1.305
# 2/2 [==============================] - 0s 5ms/step
# >4, 154/390, d1=0.580, d2=0.663 g=1.294
# 2/2 [==============================] - 0s 5ms/step
# >4, 155/390, d1=0.646, d2=0.971 g=1.241
# 2/2 [==============================] - 0s 5ms/step
# >4, 156/390, d1=0.667, d2=0.539 g=1.377
# 2/2 [==============================] - 0s 4ms/step
# >4, 157/390, d1=0.715, d2=0.652 g=1.272
# 2/2 [==============================] - 0s 5ms/step
# >4, 158/390, d1=0.611, d2=0.744 g=1.280
# 2/2 [==============================] - 0s 9ms/step
# >4, 159/390, d1=0.848, d2=0.692 g=1.263
# 2/2 [==============================] - 0s 5ms/step
# >4, 160/390, d1=0.825, d2=0.574 g=1.276
# 2/2 [==============================] - 0s 6ms/step
# >4, 161/390, d1=0.710, d2=0.645 g=1.252
# 2/2 [==============================] - 0s 6ms/step
# >4, 162/390, d1=0.768, d2=0.578 g=1.342
# 2/2 [==============================] - 0s 5ms/step
# >4, 163/390, d1=0.800, d2=0.521 g=1.382
# 2/2 [==============================] - 0s 5ms/step
# >4, 164/390, d1=0.648, d2=0.443 g=1.466
# 2/2 [==============================] - 0s 5ms/step
# >4, 165/390, d1=0.634, d2=0.666 g=1.415
# 2/2 [==============================] - 0s 4ms/step
# >4, 166/390, d1=0.567, d2=0.647 g=1.437
# 2/2 [==============================] - 0s 4ms/step
# >4, 167/390, d1=0.657, d2=0.729 g=1.303
# 2/2 [==============================] - 0s 3ms/step
# >4, 168/390, d1=0.799, d2=0.604 g=1.096
# 2/2 [==============================] - 0s 4ms/step
# >4, 169/390, d1=0.609, d2=0.769 g=1.063
# 2/2 [==============================] - 0s 5ms/step
# >4, 170/390, d1=0.579, d2=0.650 g=1.276
# 2/2 [==============================] - 0s 7ms/step
# >4, 171/390, d1=0.511, d2=0.513 g=1.582
# 2/2 [==============================] - 0s 5ms/step
# >4, 172/390, d1=0.530, d2=0.836 g=1.820
# 2/2 [==============================] - 0s 5ms/step
# >4, 173/390, d1=0.595, d2=0.376 g=1.751
# 2/2 [==============================] - 0s 6ms/step
# >4, 174/390, d1=0.477, d2=0.620 g=1.527
# 2/2 [==============================] - 0s 4ms/step
# >4, 175/390, d1=0.490, d2=0.547 g=1.604
# 2/2 [==============================] - 0s 4ms/step
# >4, 176/390, d1=0.566, d2=0.680 g=1.469
# 2/2 [==============================] - 0s 5ms/step
# >4, 177/390, d1=0.438, d2=1.178 g=2.005
# 2/2 [==============================] - 0s 5ms/step
# >4, 178/390, d1=1.053, d2=0.392 g=1.594
# 2/2 [==============================] - 0s 4ms/step
# >4, 179/390, d1=0.802, d2=0.538 g=1.229
# 2/2 [==============================] - 0s 6ms/step
# >4, 180/390, d1=0.534, d2=0.577 g=1.311
# 2/2 [==============================] - 0s 7ms/step
# >4, 181/390, d1=0.357, d2=0.563 g=1.555
# 2/2 [==============================] - 0s 4ms/step
# >4, 182/390, d1=0.356, d2=0.545 g=1.570
# 2/2 [==============================] - 0s 5ms/step
# >4, 183/390, d1=0.381, d2=0.637 g=1.687
# 2/2 [==============================] - 0s 5ms/step
# >4, 184/390, d1=0.539, d2=0.543 g=1.542
# 2/2 [==============================] - 0s 5ms/step
# >4, 185/390, d1=0.666, d2=1.013 g=1.445
# 2/2 [==============================] - 0s 5ms/step
# >4, 186/390, d1=0.708, d2=0.509 g=1.459
# 2/2 [==============================] - 0s 4ms/step
# >4, 187/390, d1=0.735, d2=0.632 g=1.328
# 2/2 [==============================] - 0s 7ms/step
# >4, 188/390, d1=0.556, d2=0.647 g=1.484
# 2/2 [==============================] - 0s 4ms/step
# >4, 189/390, d1=0.727, d2=0.635 g=1.661
# 2/2 [==============================] - 0s 4ms/step
# >4, 190/390, d1=0.642, d2=0.443 g=1.328
# 2/2 [==============================] - 0s 6ms/step
# >4, 191/390, d1=0.654, d2=0.756 g=1.147
# 2/2 [==============================] - 0s 9ms/step
# >4, 192/390, d1=0.490, d2=0.620 g=1.240
# 2/2 [==============================] - 0s 6ms/step
# >4, 193/390, d1=0.656, d2=0.592 g=1.272
# 2/2 [==============================] - 0s 5ms/step
# >4, 194/390, d1=0.574, d2=0.603 g=1.250
# 2/2 [==============================] - 0s 7ms/step
# >4, 195/390, d1=0.595, d2=0.809 g=1.382
# 2/2 [==============================] - 0s 4ms/step
# >4, 196/390, d1=0.626, d2=0.595 g=1.583
# 2/2 [==============================] - 0s 6ms/step
# >4, 197/390, d1=0.692, d2=0.954 g=1.792
# 2/2 [==============================] - 0s 11ms/step
# >4, 198/390, d1=0.791, d2=0.534 g=1.652
# 2/2 [==============================] - 0s 7ms/step
# >4, 199/390, d1=0.714, d2=0.486 g=1.561
# 2/2 [==============================] - 0s 5ms/step
# >4, 200/390, d1=0.670, d2=0.491 g=1.297
# 2/2 [==============================] - 0s 7ms/step
# >4, 201/390, d1=0.691, d2=0.627 g=1.068
# 2/2 [==============================] - 0s 5ms/step
# >4, 202/390, d1=0.592, d2=0.654 g=1.138
# 2/2 [==============================] - 0s 6ms/step
# >4, 203/390, d1=0.585, d2=0.619 g=1.257
# 2/2 [==============================] - 0s 5ms/step
# >4, 204/390, d1=0.560, d2=0.612 g=1.221
# 2/2 [==============================] - 0s 4ms/step
# >4, 205/390, d1=0.542, d2=0.656 g=1.169
# 2/2 [==============================] - 0s 5ms/step
# >4, 206/390, d1=0.461, d2=0.635 g=1.322
# 2/2 [==============================] - 0s 5ms/step
# >4, 207/390, d1=0.588, d2=0.551 g=1.411
# 2/2 [==============================] - 0s 4ms/step
# >4, 208/390, d1=0.546, d2=0.649 g=1.595
# 2/2 [==============================] - 0s 4ms/step
# >4, 209/390, d1=0.636, d2=0.497 g=1.733
# 2/2 [==============================] - 0s 5ms/step
# >4, 210/390, d1=0.633, d2=1.058 g=2.198
# 2/2 [==============================] - 0s 5ms/step
# >4, 211/390, d1=0.873, d2=0.411 g=1.733
# 2/2 [==============================] - 0s 5ms/step
# >4, 212/390, d1=0.799, d2=0.760 g=1.584
# 2/2 [==============================] - 0s 5ms/step
# >4, 213/390, d1=0.761, d2=0.678 g=1.586
# 2/2 [==============================] - 0s 5ms/step
# >4, 214/390, d1=0.674, d2=0.722 g=1.426
# 2/2 [==============================] - 0s 4ms/step
# >4, 215/390, d1=0.787, d2=0.564 g=1.992
# 2/2 [==============================] - 0s 5ms/step
# >4, 216/390, d1=0.737, d2=0.329 g=2.070
# 2/2 [==============================] - 0s 4ms/step
# >4, 217/390, d1=0.577, d2=0.772 g=1.814
# 2/2 [==============================] - 0s 4ms/step
# >4, 218/390, d1=0.800, d2=0.468 g=1.678
# 2/2 [==============================] - 0s 5ms/step
# >4, 219/390, d1=0.836, d2=0.696 g=1.398
# 2/2 [==============================] - 0s 3ms/step
# >4, 220/390, d1=0.736, d2=0.696 g=1.292
# 2/2 [==============================] - 0s 6ms/step
# >4, 221/390, d1=0.734, d2=0.608 g=1.170
# 2/2 [==============================] - 0s 5ms/step
# >4, 222/390, d1=0.679, d2=0.722 g=0.909
# 2/2 [==============================] - 0s 5ms/step
# >4, 223/390, d1=0.544, d2=0.734 g=0.932
# 2/2 [==============================] - 0s 5ms/step
# >4, 224/390, d1=0.564, d2=0.646 g=1.037
# 2/2 [==============================] - 0s 5ms/step
# >4, 225/390, d1=0.552, d2=0.599 g=1.114
# 2/2 [==============================] - 0s 5ms/step
# >4, 226/390, d1=0.585, d2=0.570 g=1.170
# 2/2 [==============================] - 0s 5ms/step
# >4, 227/390, d1=0.476, d2=0.502 g=1.343
# 2/2 [==============================] - 0s 6ms/step
# >4, 228/390, d1=0.540, d2=0.584 g=1.372
# 2/2 [==============================] - 0s 4ms/step
# >4, 229/390, d1=0.610, d2=0.745 g=1.415
# 2/2 [==============================] - 0s 5ms/step
# >4, 230/390, d1=0.553, d2=0.784 g=1.505
# 2/2 [==============================] - 0s 4ms/step
# >4, 231/390, d1=0.773, d2=0.561 g=1.328
# 2/2 [==============================] - 0s 7ms/step
# >4, 232/390, d1=0.665, d2=0.509 g=1.371
# 2/2 [==============================] - 0s 5ms/step
# >4, 233/390, d1=0.613, d2=0.700 g=1.419
# 2/2 [==============================] - 0s 5ms/step
# >4, 234/390, d1=0.750, d2=0.627 g=1.163
# 2/2 [==============================] - 0s 6ms/step
# >4, 235/390, d1=0.696, d2=0.712 g=1.188
# 2/2 [==============================] - 0s 5ms/step
# >4, 236/390, d1=0.658, d2=0.724 g=1.248
# 2/2 [==============================] - 0s 5ms/step
# >4, 237/390, d1=0.735, d2=0.679 g=1.303
# 2/2 [==============================] - 0s 5ms/step
# >4, 238/390, d1=0.826, d2=0.526 g=1.321
# 2/2 [==============================] - 0s 4ms/step
# >4, 239/390, d1=0.777, d2=0.512 g=1.332
# 2/2 [==============================] - 0s 5ms/step
# >4, 240/390, d1=0.633, d2=0.565 g=1.283
# 2/2 [==============================] - 0s 5ms/step
# >4, 241/390, d1=0.606, d2=0.614 g=1.207
# 2/2 [==============================] - 0s 5ms/step
# >4, 242/390, d1=0.661, d2=0.742 g=1.304
# 2/2 [==============================] - 0s 5ms/step
# >4, 243/390, d1=0.678, d2=0.478 g=1.280
# 2/2 [==============================] - 0s 5ms/step
# >4, 244/390, d1=0.591, d2=0.566 g=1.273
# 2/2 [==============================] - 0s 5ms/step
# >4, 245/390, d1=0.454, d2=0.575 g=1.352
# 2/2 [==============================] - 0s 5ms/step
# >4, 246/390, d1=0.478, d2=0.666 g=1.491
# 2/2 [==============================] - 0s 5ms/step
# >4, 247/390, d1=0.663, d2=0.604 g=1.540
# 2/2 [==============================] - 0s 5ms/step
# >4, 248/390, d1=0.736, d2=0.485 g=1.361
# 2/2 [==============================] - 0s 5ms/step
# >4, 249/390, d1=0.660, d2=0.562 g=1.361
# 2/2 [==============================] - 0s 5ms/step
# >4, 250/390, d1=0.541, d2=0.495 g=1.452
# 2/2 [==============================] - 0s 4ms/step
# >4, 251/390, d1=0.553, d2=0.500 g=1.291
# 2/2 [==============================] - 0s 5ms/step
# >4, 252/390, d1=0.395, d2=0.683 g=1.441
# 2/2 [==============================] - 0s 5ms/step
# >4, 253/390, d1=0.547, d2=0.668 g=1.359
# 2/2 [==============================] - 0s 5ms/step
# >4, 254/390, d1=0.592, d2=0.496 g=1.326
# 2/2 [==============================] - 0s 5ms/step
# >4, 255/390, d1=0.675, d2=0.886 g=1.417
# 2/2 [==============================] - 0s 7ms/step
# >4, 256/390, d1=0.763, d2=0.667 g=1.466
# 2/2 [==============================] - 0s 5ms/step
# >4, 257/390, d1=0.836, d2=0.779 g=1.474
# 2/2 [==============================] - 0s 5ms/step
# >4, 258/390, d1=0.972, d2=0.442 g=1.537
# 2/2 [==============================] - 0s 7ms/step
# >4, 259/390, d1=0.794, d2=0.504 g=1.472
# 2/2 [==============================] - 0s 5ms/step
# >4, 260/390, d1=0.549, d2=0.473 g=1.629
# 2/2 [==============================] - 0s 5ms/step
# >4, 261/390, d1=0.679, d2=0.679 g=1.593
# 2/2 [==============================] - 0s 5ms/step
# >4, 262/390, d1=0.763, d2=0.480 g=1.397
# 2/2 [==============================] - 0s 5ms/step
# >4, 263/390, d1=0.741, d2=0.599 g=1.136
# 2/2 [==============================] - 0s 6ms/step
# >4, 264/390, d1=0.581, d2=0.734 g=1.023
# 2/2 [==============================] - 0s 7ms/step
# >4, 265/390, d1=0.585, d2=0.717 g=1.103
# 2/2 [==============================] - 0s 9ms/step
# >4, 266/390, d1=0.627, d2=0.616 g=1.144
# 2/2 [==============================] - 0s 4ms/step
# >4, 267/390, d1=0.581, d2=0.618 g=1.213
# 2/2 [==============================] - 0s 4ms/step
# >4, 268/390, d1=0.598, d2=0.822 g=1.235
# 2/2 [==============================] - 0s 4ms/step
# >4, 269/390, d1=0.611, d2=0.747 g=1.286
# 2/2 [==============================] - 0s 9ms/step
# >4, 270/390, d1=0.774, d2=0.548 g=1.242
# 2/2 [==============================] - 0s 8ms/step
# >4, 271/390, d1=0.620, d2=0.573 g=1.372
# 2/2 [==============================] - 0s 10ms/step
# >4, 272/390, d1=0.676, d2=0.520 g=1.419
# 2/2 [==============================] - 0s 5ms/step
# >4, 273/390, d1=0.679, d2=0.533 g=1.657
# 2/2 [==============================] - 0s 4ms/step
# >4, 274/390, d1=0.547, d2=0.402 g=1.760
# 2/2 [==============================] - 0s 5ms/step
# >4, 275/390, d1=0.614, d2=0.502 g=1.598
# 2/2 [==============================] - 0s 5ms/step
# >4, 276/390, d1=0.702, d2=0.622 g=1.270
# 2/2 [==============================] - 0s 5ms/step
# >4, 277/390, d1=0.607, d2=0.827 g=1.462
# 2/2 [==============================] - 0s 5ms/step
# >4, 278/390, d1=0.495, d2=0.495 g=2.056
# 2/2 [==============================] - 0s 4ms/step
# >4, 279/390, d1=0.723, d2=0.676 g=1.367
# 2/2 [==============================] - 0s 4ms/step
# >4, 280/390, d1=0.459, d2=0.837 g=1.460
# 2/2 [==============================] - 0s 4ms/step
# >4, 281/390, d1=0.448, d2=0.719 g=1.462
# 2/2 [==============================] - 0s 6ms/step
# >4, 282/390, d1=0.492, d2=0.682 g=1.488
# 2/2 [==============================] - 0s 6ms/step
# >4, 283/390, d1=0.468, d2=0.693 g=1.911
# 2/2 [==============================] - 0s 4ms/step
# >4, 284/390, d1=0.547, d2=0.440 g=2.187
# 2/2 [==============================] - 0s 4ms/step
# >4, 285/390, d1=0.366, d2=0.402 g=2.209
# 2/2 [==============================] - 0s 3ms/step
# >4, 286/390, d1=0.468, d2=1.628 g=2.779
# 2/2 [==============================] - 0s 5ms/step
# >4, 287/390, d1=1.362, d2=1.127 g=1.659
# 2/2 [==============================] - 0s 10ms/step
# >4, 288/390, d1=1.043, d2=0.763 g=1.299
# 2/2 [==============================] - 0s 5ms/step
# >4, 289/390, d1=0.954, d2=0.526 g=1.220
# 2/2 [==============================] - 0s 4ms/step
# >4, 290/390, d1=0.802, d2=0.560 g=1.112
# 2/2 [==============================] - 0s 6ms/step
# >4, 291/390, d1=0.608, d2=0.516 g=1.228
# 2/2 [==============================] - 0s 4ms/step
# >4, 292/390, d1=0.647, d2=0.592 g=1.195
# 2/2 [==============================] - 0s 5ms/step
# >4, 293/390, d1=0.572, d2=0.549 g=1.479
# 2/2 [==============================] - 0s 4ms/step
# >4, 294/390, d1=0.731, d2=0.526 g=1.332
# 2/2 [==============================] - 0s 5ms/step
# >4, 295/390, d1=0.758, d2=0.839 g=1.309
# 2/2 [==============================] - 0s 4ms/step
# >4, 296/390, d1=0.744, d2=0.473 g=1.554
# 2/2 [==============================] - 0s 6ms/step
# >4, 297/390, d1=0.808, d2=0.519 g=1.423
# 2/2 [==============================] - 0s 6ms/step
# >4, 298/390, d1=0.659, d2=0.621 g=1.238
# 2/2 [==============================] - 0s 5ms/step
# >4, 299/390, d1=0.635, d2=0.680 g=1.192
# 2/2 [==============================] - 0s 4ms/step
# >4, 300/390, d1=0.721, d2=0.674 g=1.096
# 2/2 [==============================] - 0s 5ms/step
# >4, 301/390, d1=0.551, d2=0.689 g=1.108
# 2/2 [==============================] - 0s 5ms/step
# >4, 302/390, d1=0.622, d2=0.719 g=1.005
# 2/2 [==============================] - 0s 8ms/step
# >4, 303/390, d1=0.644, d2=0.795 g=1.085
# 2/2 [==============================] - 0s 4ms/step
# >4, 304/390, d1=0.715, d2=0.657 g=1.138
# 2/2 [==============================] - 0s 4ms/step
# >4, 305/390, d1=0.714, d2=0.579 g=1.163
# 2/2 [==============================] - 0s 5ms/step
# >4, 306/390, d1=0.722, d2=0.607 g=1.099
# 2/2 [==============================] - 0s 5ms/step
# >4, 307/390, d1=0.643, d2=0.651 g=1.044
# 2/2 [==============================] - 0s 5ms/step
# >4, 308/390, d1=0.743, d2=0.709 g=1.024
# 2/2 [==============================] - 0s 4ms/step
# >4, 309/390, d1=0.724, d2=0.589 g=1.028
# 2/2 [==============================] - 0s 4ms/step
# >4, 310/390, d1=0.679, d2=0.602 g=1.054
# 2/2 [==============================] - 0s 5ms/step
# >4, 311/390, d1=0.676, d2=0.680 g=1.036
# 2/2 [==============================] - 0s 4ms/step
# >4, 312/390, d1=0.602, d2=0.583 g=1.122
# 2/2 [==============================] - 0s 4ms/step
# >4, 313/390, d1=0.633, d2=0.583 g=1.144
# 2/2 [==============================] - 0s 4ms/step
# >4, 314/390, d1=0.573, d2=0.568 g=1.129
# 2/2 [==============================] - 0s 5ms/step
# >4, 315/390, d1=0.595, d2=0.590 g=1.100
# 2/2 [==============================] - 0s 5ms/step
# >4, 316/390, d1=0.614, d2=0.706 g=1.102
# 2/2 [==============================] - 0s 4ms/step
# >4, 317/390, d1=0.634, d2=0.780 g=1.273
# 2/2 [==============================] - 0s 4ms/step
# >4, 318/390, d1=0.679, d2=0.572 g=1.185
# 2/2 [==============================] - 0s 5ms/step
# >4, 319/390, d1=0.786, d2=0.617 g=1.205
# 2/2 [==============================] - 0s 4ms/step
# >4, 320/390, d1=0.731, d2=0.612 g=1.295
# 2/2 [==============================] - 0s 4ms/step
# >4, 321/390, d1=0.743, d2=0.588 g=1.338
# 2/2 [==============================] - 0s 5ms/step
# >4, 322/390, d1=0.606, d2=0.539 g=1.325
# 2/2 [==============================] - 0s 4ms/step
# >4, 323/390, d1=0.542, d2=0.613 g=1.412
# 2/2 [==============================] - 0s 5ms/step
# >4, 324/390, d1=0.557, d2=0.610 g=1.494
# 2/2 [==============================] - 0s 5ms/step
# >4, 325/390, d1=0.630, d2=0.637 g=1.353
# 2/2 [==============================] - 0s 6ms/step
# >4, 326/390, d1=0.630, d2=0.516 g=1.291
# 2/2 [==============================] - 0s 5ms/step
# >4, 327/390, d1=0.698, d2=0.571 g=1.222
# 2/2 [==============================] - 0s 5ms/step
# >4, 328/390, d1=0.472, d2=0.735 g=1.443
# 2/2 [==============================] - 0s 4ms/step
# >4, 329/390, d1=0.570, d2=0.696 g=1.613
# 2/2 [==============================] - 0s 6ms/step
# >4, 330/390, d1=0.790, d2=0.728 g=1.281
# 2/2 [==============================] - 0s 5ms/step
# >4, 331/390, d1=0.574, d2=0.566 g=1.446
# 2/2 [==============================] - 0s 5ms/step
# >4, 332/390, d1=0.628, d2=0.578 g=1.345
# 2/2 [==============================] - 0s 5ms/step
# >4, 333/390, d1=0.498, d2=0.666 g=1.370
# 2/2 [==============================] - 0s 5ms/step
# >4, 334/390, d1=0.603, d2=0.535 g=1.554
# 2/2 [==============================] - 0s 5ms/step
# >4, 335/390, d1=0.499, d2=0.548 g=1.636
# 2/2 [==============================] - 0s 7ms/step
# >4, 336/390, d1=0.477, d2=0.504 g=1.654
# 2/2 [==============================] - 0s 5ms/step
# >4, 337/390, d1=0.404, d2=0.490 g=1.405
# 2/2 [==============================] - 0s 9ms/step
# >4, 338/390, d1=0.457, d2=1.518 g=1.756
# 2/2 [==============================] - 0s 9ms/step
# >4, 339/390, d1=0.926, d2=0.431 g=1.458
# 2/2 [==============================] - 0s 5ms/step
# >4, 340/390, d1=0.782, d2=0.560 g=1.377
# 2/2 [==============================] - 0s 18ms/step
# >4, 341/390, d1=0.800, d2=0.472 g=1.332
# 2/2 [==============================] - 0s 8ms/step
# >4, 342/390, d1=0.533, d2=0.700 g=1.382
# 2/2 [==============================] - 0s 6ms/step
# >4, 343/390, d1=0.598, d2=0.805 g=1.500
# 2/2 [==============================] - 0s 5ms/step
# >4, 344/390, d1=0.619, d2=0.449 g=1.468
# 2/2 [==============================] - 0s 5ms/step
# >4, 345/390, d1=0.698, d2=0.553 g=1.388
# 2/2 [==============================] - 0s 6ms/step
# >4, 346/390, d1=0.617, d2=0.653 g=1.333
# 2/2 [==============================] - 0s 5ms/step
# >4, 347/390, d1=0.692, d2=0.691 g=1.216
# 2/2 [==============================] - 0s 5ms/step
# >4, 348/390, d1=0.531, d2=0.634 g=1.270
# 2/2 [==============================] - 0s 5ms/step
# >4, 349/390, d1=0.581, d2=0.592 g=1.280
# 2/2 [==============================] - 0s 5ms/step
# >4, 350/390, d1=0.623, d2=0.611 g=1.174
# 2/2 [==============================] - 0s 5ms/step
# >4, 351/390, d1=0.550, d2=1.011 g=1.299
# 2/2 [==============================] - 0s 5ms/step
# >4, 352/390, d1=0.695, d2=0.391 g=1.462
# 2/2 [==============================] - 0s 5ms/step
# >4, 353/390, d1=0.572, d2=0.472 g=1.514
# 2/2 [==============================] - 0s 4ms/step
# >4, 354/390, d1=0.485, d2=0.612 g=1.517
# 2/2 [==============================] - 0s 5ms/step
# >4, 355/390, d1=0.486, d2=0.637 g=1.587
# 2/2 [==============================] - 0s 5ms/step
# >4, 356/390, d1=0.647, d2=0.506 g=1.557
# 2/2 [==============================] - 0s 5ms/step
# >4, 357/390, d1=0.587, d2=0.722 g=1.432
# 2/2 [==============================] - 0s 5ms/step
# >4, 358/390, d1=0.594, d2=0.749 g=1.597
# 2/2 [==============================] - 0s 4ms/step
# >4, 359/390, d1=0.737, d2=0.510 g=1.647
# 2/2 [==============================] - 0s 5ms/step
# >4, 360/390, d1=0.612, d2=1.064 g=1.411
# 2/2 [==============================] - 0s 4ms/step
# >4, 361/390, d1=0.848, d2=1.257 g=1.725
# 2/2 [==============================] - 0s 4ms/step
# >4, 362/390, d1=1.064, d2=0.438 g=1.241
# 2/2 [==============================] - 0s 6ms/step
# >4, 363/390, d1=0.699, d2=0.701 g=1.165
# 2/2 [==============================] - 0s 5ms/step
# >4, 364/390, d1=0.539, d2=0.793 g=1.207
# 2/2 [==============================] - 0s 5ms/step
# >4, 365/390, d1=0.746, d2=0.602 g=1.241
# 2/2 [==============================] - 0s 4ms/step
# >4, 366/390, d1=0.703, d2=0.580 g=1.272
# 2/2 [==============================] - 0s 5ms/step
# ...
# 2/2 [==============================] - 0s 6ms/step
# >10, 70/390, d1=0.580, d2=0.708 g=0.948
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 54%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 71/390, d1=0.659, d2=1.041 g=0.973
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 43%, fake: 87%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 72/390, d1=0.734, d2=1.944 g=0.852
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 65%, fake: 58%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 73/390, d1=0.631, d2=1.805 g=0.911
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 57%, fake: 45%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 8ms/step
# >10, 74/390, d1=0.588, d2=3.185 g=1.067
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 45%, fake: 74%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 75/390, d1=0.758, d2=1.070 g=1.002
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 54%, fake: 21%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 76/390, d1=0.852, d2=1.886 g=0.393
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 69%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 9ms/step
# >10, 77/390, d1=0.863, d2=4.846 g=4.298
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 7%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 78/390, d1=2.079, d2=0.665 g=3.208
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 13%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 79/390, d1=2.152, d2=2.169 g=0.910
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 56%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 80/390, d1=0.577, d2=0.818 g=0.966
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 52%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 81/390, d1=0.639, d2=1.153 g=1.109
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 33%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 82/390, d1=1.108, d2=0.842 g=1.031
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 16%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 83/390, d1=0.822, d2=0.611 g=1.085
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 23%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 12ms/step
# >10, 84/390, d1=0.815, d2=0.611 g=1.138
# 5/5 [==============================] - 0s 7ms/step
# >Accuracy real: 27%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 85/390, d1=0.767, d2=0.652 g=1.035
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 38%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 86/390, d1=0.660, d2=0.801 g=0.983
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 48%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 87/390, d1=0.750, d2=0.662 g=0.898
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 39%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 88/390, d1=0.753, d2=0.843 g=0.790
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 47%, fake: 59%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 11ms/step
# >10, 89/390, d1=0.707, d2=0.766 g=0.784
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 54%, fake: 57%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 90/390, d1=0.720, d2=0.831 g=0.824
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 48%, fake: 66%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 91/390, d1=0.678, d2=0.724 g=0.864
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 55%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 92/390, d1=0.680, d2=0.695 g=0.858
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 51%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 8ms/step
# >10, 93/390, d1=0.685, d2=0.697 g=0.943
# 5/5 [==============================] - 0s 7ms/step
# >Accuracy real: 59%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 94/390, d1=0.720, d2=0.673 g=0.922
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 58%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 95/390, d1=0.598, d2=0.705 g=0.926
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 60%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 96/390, d1=0.697, d2=0.748 g=0.896
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 66%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 97/390, d1=0.686, d2=0.731 g=0.885
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 59%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 8ms/step
# >10, 98/390, d1=0.595, d2=0.711 g=0.856
# 5/5 [==============================] - 0s 7ms/step
# >Accuracy real: 50%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 99/390, d1=0.617, d2=0.667 g=0.882
# 5/5 [==============================] - 0s 7ms/step
# >Accuracy real: 44%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 100/390, d1=0.687, d2=0.785 g=0.917
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 39%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 101/390, d1=0.677, d2=0.684 g=0.858
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 46%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 102/390, d1=0.777, d2=0.773 g=0.846
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 41%, fake: 70%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 103/390, d1=0.733, d2=0.699 g=0.822
# 5/5 [==============================] - 0s 7ms/step
# >Accuracy real: 42%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 104/390, d1=0.797, d2=0.720 g=0.850
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 31%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 105/390, d1=0.722, d2=0.687 g=0.842
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 43%, fake: 70%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 106/390, d1=0.763, d2=0.692 g=0.845
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 44%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 107/390, d1=0.728, d2=0.664 g=0.848
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 39%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 108/390, d1=0.721, d2=0.733 g=0.886
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 37%, fake: 80%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 9ms/step
# >10, 109/390, d1=0.752, d2=0.670 g=0.953
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 38%, fake: 83%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 110/390, d1=0.762, d2=0.615 g=0.852
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 37%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 111/390, d1=0.741, d2=0.683 g=0.859
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 41%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 13ms/step
# >10, 112/390, d1=0.710, d2=0.657 g=0.831
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 37%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 8ms/step
# >10, 113/390, d1=0.750, d2=0.717 g=0.789
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 40%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 7ms/step
# >10, 114/390, d1=0.690, d2=0.726 g=0.790
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 39%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 6ms/step
# >10, 115/390, d1=0.721, d2=0.664 g=0.835
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 39%, fake: 70%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 17ms/step
# >10, 116/390, d1=0.708, d2=0.680 g=0.847
# 5/5 [==============================] - 0s 6ms/step
# >Accuracy real: 43%, fake: 80%

# %%
# example of loading the generator model and generating images
from keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
 # generate points in the latent space
 x_input = randn(latent_dim * n_samples)
 # reshape into a batch of inputs for the network
 x_input = x_input.reshape(n_samples, latent_dim)
 return x_input

# plot the generated images
def create_plot(examples, n):
  # plot images
  for i in range(n * n):
    # define subplot
    pyplot.subplot(n, n, 1 + i)
    # turn off axis
    pyplot.axis('off')
    # plot raw pixel data
    pyplot.imshow(examples[i, :, :])
    pyplot.show()

# load model
model = load_model('generator_model_010.h5')
# generate images
latent_points = generate_latent_points(100, 100)
# generate images
X = model.predict(latent_points)
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
# plot the result
create_plot(X, 10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 2s 53ms/step
